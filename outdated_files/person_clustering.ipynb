# %% [markdown]
# # Setup

# %%
import sys
import os
import dlib
import glob
import time

import cv2
import os

import matplotlib.pyplot as plt

from face_classifier import FaceClassifier

import random
import torch
import numpy as np

import calc
import icio
import postproc

print(dlib.DLIB_USE_CUDA)
print(cv2.__version__)
# Out:
# True
# 4.5.5

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # type: ignore
    torch.backends.cudnn.deterministic = True  # type: ignore
    torch.backends.cudnn.benchmark = False  # type: ignore

seed_everything(79)

# %%
# Activating gpu
import face_recognition

def check_use_gpu(TARGET_IMG_PATH):
    image = face_recognition.load_image_file(TARGET_IMG_PATH)
    face_locations = face_recognition.face_locations(image,model='cnn')
    if len(face_locations) > 0:
        print('Using GPU')
    else:
        print('***Not using GPU***')

person_img = "/opt/ml/person-clustering/test.jpg" # person image
check_use_gpu(person_img)
# Out:
# Using GPU

# %% [markdown]
# # Extract frame from video and save as images

# %%
video_paths = {
    0: "/opt/ml/project/test_videos/giha_before_13m.mp4",
}

# %%
file_num = 0

filepath = video_paths[file_num]
video = cv2.VideoCapture(filepath)

assert video.isOpened(), f"Could not Open : {filepath}"

# %%
# 불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
# Out:
# length : 19153
# width : 1280
# height : 720
# fps : 23.999999665848698

# %%
# 변수 설정
frame_batch_size = 16
face_cloth_weights = [1.0, 1.0]
capture_interval = 3 * int(round(fps)) # n초 간격 프레임 캡쳐
stop = 0 # 0 초과의 정수 지정 시 n 초 까지만 영상 실행
skip = 0 # 초반 n 초 skip
face_cnt = 350 # 몇 장의 인물 사진을 사용할 지
resizing_ratio = None # frame resizing ratio (0.0 ~ 1.0)
resizing_resolution = 1000 # 해당 값 이상의 해상도(너비)를 가지는 영상에 대해 resizing 적용
result_dir = filepath[:-4] + '_result_images_face_cloth' # 결과가 저장될 디렉토리

# %%
try:
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
except OSError:
    print('Error: Creaing directory. ' + result_dir)

# %%
video = cv2.VideoCapture(filepath) 

# FaceClssifier
fc = FaceClassifier(result_dir)

fingerprints = dict()

frames = []
frame_idx = 0

running = True

# Scene Detection
use_scene_transition = False

last_down_frame = None
last_org_frame = None
        
start_frame_idx = 0
start_down_frame = None
start_org_frame = None
min_scene_frames = 15
timelines = []
down_scale_factor = 8
transition_threshold = 100


total_start = time.time()
while running:
    ret, frame = video.read()

    if frame is None:
        break

    seconds = int(round(frame_idx / fps, 3))
    # print(f"Running in {seconds} sec in video...")
    if seconds > stop > 0:
        break
    if seconds < skip:
        frame_idx += 1
        continue

    ###### Frame extraction ######
    if use_scene_transition:
        cur_down_frame = frame[::down_scale_factor, ::down_scale_factor, :]
                
        if last_down_frame is None:
            last_down_frame = cur_down_frame
            last_org_frame = frame
            start_frame_idx = frame_idx
            start_down_frame = cur_down_frame
            start_org_frame = frame
            frame_idx += 1
            continue
                    
        num_pixels = cur_down_frame.shape[0] * cur_down_frame.shape[1]
        rgb_distance = np.abs(cur_down_frame - last_down_frame) / float(num_pixels)
        rgb_distance = rgb_distance.sum() / 3.0
                
        if rgb_distance > transition_threshold and frame_idx - start_frame_idx > min_scene_frames:
            # print("({}~{})".format(start_frame_idx, frame_idx-1))  
            # resize frame
            if resizing_ratio and frame.shape[1] >= resizing_resolution:
                start_org_frame = cv2.resize(start_org_frame, None, fx=resizing_ratio, fy=resizing_ratio)
                last_org_frame = cv2.resize(last_org_frame, None, fx=resizing_ratio, fy=resizing_ratio)      
            frames.append(start_org_frame)
            frames.append(last_org_frame)
                    
            start_frame_idx = frame_idx
            start_down_frame = cur_down_frame
            start_org_frame = frame
                
        last_down_frame = cur_down_frame
        last_org_frame = frame
    else:
        if frame_idx % capture_interval == 0:
            # resize frame
            if resizing_ratio and frame.shape[1] >= resizing_resolution:
                frame = cv2.resize(frame, None, fx=resizing_ratio, fy=resizing_ratio)
            frames.append(frame)
            
    ###### detect_faces ######
    if len(frames) < frame_batch_size:
        frame_idx += 1
        continue        
    else:
        frame_fingerprints = fc.detect_faces(frames, frame_batch_size, face_cloth_weights)
        if frame_fingerprints:
            fingerprints.update(frame_fingerprints)
            print('# of face images: ', len(fingerprints))
            print('# of frames: ', frame_idx)
            print()   
        frames = []
    
    ###### finish loop ######
    if len(fingerprints) >= face_cnt:
        break
    
    frame_idx += 1


running = False
video.release()
print()

total_end = time.time()
print('Inference time: ',total_end-total_start)
print("Captured frames : ", frame_idx)
# Out:
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-0.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-1.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-2.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-3.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-4.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-5.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-6.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-7.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-8.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-9.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-10.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-11.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-12.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-13.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-14.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-15.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-16.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-17.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-18.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-19.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-20.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-21.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-22.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-23.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-24.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-25.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-26.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152518.842-27.png
# Face images:  28
# frame_cnt:  1
#
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-0.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-1.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-2.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-3.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-4.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-5.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-6.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-7.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-8.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-9.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-10.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-11.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-12.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-13.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-14.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-15.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-16.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-17.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-18.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-19.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-20.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-21.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-22.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-23.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-24.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152526.436-25.png
# Face images:  54
# frame_cnt:  2
#
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-0.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-1.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-2.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-3.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-4.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-5.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-6.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-7.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-8.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-9.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-10.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-11.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-12.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-13.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-14.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-15.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-16.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-17.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-18.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-19.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-20.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-21.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-22.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-23.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-24.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-25.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-26.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-27.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-28.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-29.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152528.796-30.png
# Face images:  85
# frame_cnt:  3
#
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-0.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-1.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-2.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-3.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-4.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-5.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-6.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-7.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-8.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-9.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-10.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152531.185-11.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_
png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-24.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-25.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-26.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-27.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-28.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-29.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-30.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-31.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-32.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-33.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-34.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-35.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152544.909-36.png
# Face images:  290
# frame_cnt:  10
#
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-0.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-1.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-2.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-3.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-4.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-5.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-6.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-7.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-8.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-9.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-10.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-11.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-12.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-13.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-14.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-15.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-16.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-17.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-18.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-19.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-20.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-21.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-22.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-23.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-24.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-25.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-26.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152547.433-27.png
# Face images:  318
# frame_cnt:  11
#
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-0.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-1.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-2.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-3.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-4.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-5.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-6.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-7.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-8.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-9.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-10.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-11.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-12.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-13.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-14.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-15.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-16.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-17.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-18.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-19.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-20.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-21.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-22.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152549.843-23.png
# Face images:  342
# frame_cnt:  12
#
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-0.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-1.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-2.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-3.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-4.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-5.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-6.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-7.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-8.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-9.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-10.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-11.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-12.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-13.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-14.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-15.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-16.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-17.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-18.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-19.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-20.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-21.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-22.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-23.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-24.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-25.png
# image saved path:  /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/20220612_152552.359-26.png
# Face images:  369
# frame_cnt:  13
#
#
# Inference time:  37.107603311538696
# Captured frames :  14904

# %% [markdown]
# # Clustering

# %%
# 클러스터링(fingerprints) 후 결과 출력
clusters = calc.cluster(fingerprints, sim=0.63, min_csize=4) # the higher, the stricter

postproc.make_links(clusters, os.path.join(result_dir, 'imagecluster/clusters'))

images = icio.read_images(result_dir, size=(224,224))

fig, ax = postproc.plot_clusters(clusters, images)
fig.savefig(os.path.join(result_dir, 'imagecluster/_cluster.png'))
postproc.plt.show()
# Out:
# #images : #clusters
# 4 : 5
# 5 : 3
# 6 : 3
# 7 : 1
# 8 : 2
# 10 : 1
# 12 : 1
# 13 : 2
# 25 : 1
# 27 : 1
# #images in clusters total:  176
# cluster dir: /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/imagecluster/clusters
# plot array (uint8) size: 77.51953125 MiB

# %%
# After merging
FACE_THRESHOLD_HARD = 0.18
CLOTH_THRESHOLD_HARD = 0.12
merged_clusters = postproc.merge_clusters(clusters, fingerprints, FACE_THRESHOLD_HARD, CLOTH_THRESHOLD_HARD, iteration=1)

postproc.make_links(merged_clusters, os.path.join(result_dir, 'imagecluster/merged_clusters'))

images = icio.read_images(result_dir, size=(224,224))

fig, ax = postproc.plot_clusters(merged_clusters, images)
fig.savefig(os.path.join(result_dir, 'imagecluster/_merged_cluster.png'))
postproc.plt.show()
# Out:
# cluster dir: /opt/ml/project/test_videos/giha_before_13m_result_images_face_cloth/imagecluster/merged_clusters
# plot array (uint8) size: 132.64453125 MiB
